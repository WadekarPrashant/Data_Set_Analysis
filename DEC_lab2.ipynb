
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03    2456.000000
# mean   1247.410903  1247.799926  5.096721e+05  6.942919e+13   41346.011401
# std    1074.476439  1075.057438  8.535993e+05  1.443973e+14   36435.449733
# ...

# %%
data.shape
# Out:
# (5306, 15)

# %%
data.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
#slice the result for first 5 rows
print (data[0:5]['Prev Close'])
# Out:
# 0    361.20
# 1    381.65
# 2    385.55
# 3    383.00
# 4    377.50
# Name: Prev Close, dtype: float64

# %%
print (data[0:5]['High'])
# Out:
# 0    390.0
# 1    392.0
# 2    390.0
# 3    384.9
# 4    390.0
# Name: High, dtype: float64

# %%
#slice the result for first 5 rows
print (data[0:5]['Low'])
# Out:
# 0    370.0
# 1    375.0
# 2    371.5
# 3    374.5
# 4    370.0
# Name: Low, dtype: float64

# %%
#Reading specific columns
print (data.loc[:,['Low','High']])
# Out:
#           Low     High
# 0      370.00   390.00
# 1      375.00   392.00
# 2      371.50   390.00
# 3      374.50   384.90
# 4      370.00   390.00
# ...       ...      ...
# 5301  2530.00  2575.00
# 5302  2534.00  2579.90
# 5303  2575.00  2620.25
# 5304  2570.00  2642.00
# 5305  2524.05  2605.80
#
# [5306 rows x 2 columns]

# %%
#Reading specific columns
print (data.loc[:,['Volume','Turnover']])
# Out:
#        Volume      Turnover
# 0        3318  1.262617e+11
# 1        4818  1.847699e+11
# 2        2628  9.981384e+10
# 3        3354  1.274114e+11
# 4        9589  3.676275e+11
# ...       ...           ...
# 5301  1103980  2.823400e+14
# 5302   866331  2.218288e+14
# 5303  1065561  2.776752e+14
# 5304  1295346  3.377394e+14
# 5305  1384907  3.543512e+14
#
# [5306 rows x 2 columns]

# %%
data['Low'].median()
# Out:
# 878.075

# %%
data['Low'].mean()
# Out:
# 1230.9006973237842

# %%
data['Low'].mode()
# Out:
# 0    310.0
# 1    320.0
# Name: Low, dtype: float64

# %%
#Display the null values
data.isnull()
# Out:
#        Date  Symbol  Series  Prev Close   Open   High    Low   Last  Close  \
# 0     False   False   False       False  False  False  False  False  False
# 1     False   False   False       False  False  False  False  False  False
# 2     False   False   False       False  False  False  False  False  False
# 3     False   False   False       False  False  False  False  False  False
# 4     False   False   False       False  False  False  False  False  False
# ...     ...     ...     ...         ...    ...    ...    ...    ...    ...
# 5301  False   False   False       False  False  False  False  False  False
# 5302  False   False   False       False  False  False  False  False  False
# 5303  False   False   False       False  False  False  False  False  False
# 5304  False   False   False       False  False  False  False  False  False
# 5305  False   False   False       False  False  False  False  False  False
#
# ...

# %%
#Sum of all null values
data.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# dtype: int64

# %%
# Printing null values from High column
print(data['High'].isnull())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5301    False
# 5302    False
# 5303    False
# 5304    False
# 5305    False
# Name: High, Length: 5306, dtype: bool

# %%
data['Low'].mean()
# Out:
# 1230.9006973237842

# %%
# Drop rows with missing values
#print(data.dropna(inplace = False))
data.dropna(inplace = False)
data.shape
# Out:
# (5306, 15)

# %%
data.fillna(0)
# Out:
#             Date      Symbol Series  Prev Close    Open     High      Low  \
# 0     2000-01-03  ASIANPAINT     EQ      361.20   370.0   390.00   370.00
# 1     2000-01-04  ASIANPAINT     EQ      381.65   380.0   392.00   375.00
# 2     2000-01-05  ASIANPAINT     EQ      385.55   371.5   390.00   371.50
# 3     2000-01-06  ASIANPAINT     EQ      383.00   384.9   384.90   374.50
# 4     2000-01-07  ASIANPAINT     EQ      377.50   376.0   390.00   370.00
# ...          ...         ...    ...         ...     ...      ...      ...
# 5301  2021-04-26  ASIANPAINT     EQ     2517.95  2530.0  2575.00  2530.00
# 5302  2021-04-27  ASIANPAINT     EQ     2557.90  2545.0  2579.90  2534.00
# 5303  2021-04-28  ASIANPAINT     EQ     2574.35  2588.0  2620.25  2575.00
# 5304  2021-04-29  ASIANPAINT     EQ     2614.55  2630.0  2642.00  2570.00
# 5305  2021-04-30  ASIANPAINT     EQ     2613.45  2595.0  2605.80  2524.05
#
#         Last    Close     VWAP   Volume      Turnover   Trades  \
# ...

# %%
# Getting the mean values
# Adding mean values in place of null values
mean_values = data.mean()
#data_filled=data.fillna(mean_values)
#print(data_filled)
print(mean_values)
# Out:
# Prev Close            1.247001e+03
# Open                  1.247684e+03
# High                  1.264625e+03
# Low                   1.230901e+03
# Last                  1.247317e+03
# Close                 1.247411e+03
# VWAP                  1.247800e+03
# Volume                5.096721e+05
# Turnover              6.942919e+13
# Trades                4.134601e+04
# Deliverable Volume    2.751281e+05
# %Deliverble           6.255724e-01
# dtype: float64
# <ipython-input-39-d78786fb8b9c>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values = data.mean()

# %%
# Getting the median of all data
median_values = data.median()
print(median_values)
# Out:
# Prev Close            8.893750e+02
# Open                  8.900000e+02
# High                  9.039750e+02
# Low                   8.780750e+02
# Last                  8.900000e+02
# Close                 8.894750e+02
# VWAP                  8.883500e+02
# Volume                5.713600e+04
# Turnover              1.109437e+13
# Trades                3.240250e+04
# Deliverable Volume    5.273800e+04
# %Deliverble           6.161000e-01
# dtype: float64
# <ipython-input-40-15bbc1801f7c>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median_values = data.median()

# %%
data['Low'].mean()
# Out:
# 1230.9006973237842

# %%
data.duplicated
# Out:
# <bound method DataFrame.duplicated of             Date      Symbol Series  Prev Close    Open     High      Low  \
# 0     2000-01-03  ASIANPAINT     EQ      361.20   370.0   390.00   370.00
# 1     2000-01-04  ASIANPAINT     EQ      381.65   380.0   392.00   375.00
# 2     2000-01-05  ASIANPAINT     EQ      385.55   371.5   390.00   371.50
# 3     2000-01-06  ASIANPAINT     EQ      383.00   384.9   384.90   374.50
# 4     2000-01-07  ASIANPAINT     EQ      377.50   376.0   390.00   370.00
# ...          ...         ...    ...         ...     ...      ...      ...
# 5301  2021-04-26  ASIANPAINT     EQ     2517.95  2530.0  2575.00  2530.00
# 5302  2021-04-27  ASIANPAINT     EQ     2557.90  2545.0  2579.90  2534.00
# 5303  2021-04-28  ASIANPAINT     EQ     2574.35  2588.0  2620.25  2575.00
# 5304  2021-04-29  ASIANPAINT     EQ     2614.55  2630.0  2642.00  2570.00
# 5305  2021-04-30  ASIANPAINT     EQ     2613.45  2595.0  2605.80  2524.05
#
# ...

# %%
data.plot('Date','High')
# Out:
# <Axes: xlabel='Date'>

# %%
data.plot('Date','Volume')
# Out:
# <Axes: xlabel='Date'>

# %%
data.plot('Date','Turnover')
# Out:
# <Axes: xlabel='Date'>
