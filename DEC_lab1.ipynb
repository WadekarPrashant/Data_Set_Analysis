# %% [markdown]
# <a href="https://colab.research.google.com/github/WadekarPrashant/Data_Set_Analysis/blob/main/DEC_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('popular_10000_movies_tmdb.csv')

# %%
# Getting the size
data.size
# Out:
# 140000

# %%
# Getting the shape rows x columns
data.shape
# Out:
# (10000, 14)

# %%
# Getting the head(20) top 20 rows
data.head(40)
# Out:
#          id                                              title release_date  \
# 0    758323                                The Pope's Exorcist   2023-04-05
# 1    640146                  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2    502356                        The Super Mario Bros. Movie   2023-04-05
# 3    868759                                            Ghosted   2023-04-18
# 4    594767                           Shazam! Fury of the Gods   2023-03-15
# 5     76600                           Avatar: The Way of Water   2022-12-14
# 6    447365                   Guardians of the Galaxy Volume 3   2023-05-03
# 7    934433                                          Scream VI   2023-03-08
# 8    677179                                          Creed III   2023-03-01
# 9    493529            Dungeons & Dragons: Honor Among Thieves   2023-03-23
# 10   948713             The Last Kingdom: Seven Kings Must Die   2023-04-14
# ...

# %%
# Getting the tail(10) bottom 10 rows
data.tail(10)
# Out:
#           id                                             title release_date  \
# 9990   10748                                     St. Trinian's   2007-12-21
# 9991  917269  The Witcher Season One Recap: From the Beginning   2021-12-17
# 9992  914216                                     The Lost King   2022-10-07
# 9993  823461                                     Good on Paper   2021-06-23
# 9994   94503    Tsubasa RESERVoir CHRoNiCLE: Tokyo Revelations   2007-11-16
# 9995  374473                                   I, Daniel Blake   2016-10-21
# 9996   16774                 Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564                   Return to House on Haunted Hill   2007-10-03
# 9998  482204                            My Sister-in-law's Job   2017-08-31
# 9999  444539                                      The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# ...

# %%
# sorting the values by id
data.sort_values(by=['id'])
# Out:
#            id                      title release_date  \
# 5851        5                 Four Rooms   1995-12-09
# 351        11                  Star Wars   1977-05-25
# 513        12               Finding Nemo   2003-05-30
# 884        13               Forrest Gump   1994-06-23
# 2985       14            American Beauty   1999-09-15
# ...       ...                        ...          ...
# 5967  1119471                    Vamoose   2023-05-09
# 4190  1119600  How Not to Win Eurovision   2023-05-08
# 6410  1119744                   Fall Guy   2023-05-12
# 7033  1119787              Issac Ender’s   2023-05-10
# 9922  1119921              Mental Finger   2023-05-06
#
#                                           genres original_language  \
# 5851                         ['Crime', 'Comedy']           English
# 351   ['Adventure', 'Action', 'Science Fiction']           English
# 513                      ['Animation', 'Family']           English
# ...

# %%
# Getting the summary
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10000 non-null  int64
#  1   title                 10000 non-null  object
#  2   release_date          9979 non-null   object
#  3   genres                10000 non-null  object
#  4   original_language     10000 non-null  object
#  5   vote_average          10000 non-null  float64
#  6   vote_count            10000 non-null  int64
#  7   popularity            10000 non-null  float64
#  8   overview              9923 non-null   object
#  9   budget                10000 non-null  int64
#  10  production_companies  10000 non-null  object
#  11  revenue               10000 non-null  int64
#  12  runtime               10000 non-null  int64
#  13  tagline               7241 non-null   object
# dtypes: float64(2), int64(5), object(7)
# ...

# %%
# Gets the row labels
data.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
# Describing the data
data.describe
# Out:
# <bound method NDFrame.describe of           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# ...

# %%
# Getting the null values
data.dropna()
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# 5      76600           Avatar: The Way of Water   2022-12-14
# ...      ...                                ...          ...
# 9989   21500                              Class   1983-07-22
# 9990   10748                      St. Trinian's   2007-12-21
# 9992  914216                      The Lost King   2022-10-07
# 9993  823461                      Good on Paper   2021-06-23
# 9999  444539                       The Bookshop   2017-11-10
#
#                                             genres original_language  \
# 0                ['Horror', 'Mystery', 'Thriller']           English
# 1       ['Action', 'Adventure', 'Science Fiction']           English
# ...

# %%
# Replacing the null values with 0
data.fillna(0)
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# ...

# %%
# Getting the mean values
# Adding mean values in place of null values
mean_values = data.mean()
data_filled=data.fillna(mean_values)
print(data_filled)
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# ...

# %%
# maximum data it can occupy
data.memory_usage()
# Out:
# Index                     128
# id                      80000
# title                   80000
# release_date            80000
# genres                  80000
# original_language       80000
# vote_average            80000
# vote_count              80000
# popularity              80000
# overview                80000
# budget                  80000
# production_companies    80000
# revenue                 80000
# runtime                 80000
# tagline                 80000
# dtype: int64

# %%
data.memory_usage(index= True)
# Out:
# Index                     128
# id                      80000
# title                   80000
# release_date            80000
# genres                  80000
# original_language       80000
# vote_average            80000
# vote_count              80000
# popularity              80000
# overview                80000
# budget                  80000
# production_companies    80000
# revenue                 80000
# runtime                 80000
# tagline                 80000
# dtype: int64
